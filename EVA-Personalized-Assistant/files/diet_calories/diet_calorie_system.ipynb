# %%
import pandas as pd
import pickle

# Sample input data
sample_data = pd.DataFrame({
    'Age': [23],
    'Gender': [0],  # Assuming 'Female' is encoded as 1 in your model
    'Weight (kg)': [72.5],
    'Height (cm)': [172.7],
    'Activity Level': ['Very Active'],  # Assuming 'Lightly Active' is encoded as appropriate values
    'Goal': ['Lose'],  # Assuming 'Lose' is encoded as appropriate values
    'Target Weight (kg)': [68.5],
    'Dietary Preferences': ['None']  # Assuming 'Gluten-Free' is encoded as appropriate values
})

# Load the saved model using pickle
model_filename = '/content/diet_model.pkl'
with open(model_filename, 'rb') as file:
    loaded_model = pickle.load(file)

# Load the saved preprocessing using pickle
preprocess_filename = '/content/preprocess.pkl'
with open(preprocess_filename, 'rb') as file:
    loaded_preprocess = pickle.load(file)

# Create the same ColumnTransformer and apply it to the sample data
categorical_features = ['Gender', 'Activity Level', 'Goal', 'Dietary Preferences']
numeric_features = ['Age', 'Weight', 'Height', 'Target Weight']
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# Preprocess the sample data
sample_data_preprocessed = loaded_preprocess.transform(sample_data)

# Make predictions
predictions = loaded_model.predict(sample_data_preprocessed)

# Print the predicted values
print('Predicted Maintenance Calories:', predictions[0][0])
print('Predicted Carbohydrates:', predictions[0][1])
print('Predicted Proteins:', predictions[0][2])
print('Predicted Fats:', predictions[0][3])
print('Predicted Fiber:', predictions[0][4])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-3f64a0ef7248> in <cell line: 42>()
#      40
#      41 # Make predictions
# ---> 42 predictions = loaded_model.predict(sample_data_preprocessed)
#      43
#      44 # Print the predicted values
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in predict(self, X, **predict_params)
#     478         Xt = X
#     479         for _, name, transform in self._iter(with_final=False):
# --> 480             Xt = transform.transform(Xt)
#     481         return self.steps[-1][1].predict(Xt, **predict_params)
#     482
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
# ...
