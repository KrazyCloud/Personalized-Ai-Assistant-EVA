# %% [markdown]
# # ***Recommendation***

# %%
import pandas as pd

# %%
data = [
    ("Excited about starting a new adventure.", "Pop"),
    ("Feeling nostalgic for the good old days.", "Oldies"),
    ("Trying to focus and be productive at work.", "Classical"),
    ("Diving into the timeless beauty of classical compositions.", "Classical"),
    ("Journeying through history with the elegance of classical music.", "Classical"),
    ("Finding solace in the intricate melodies of classical masterpieces.", "Classical"),
    ("Embracing the symphonic emotions of classical orchestras.", "Classical"),
    ("Savoring the tranquility of classical piano sonatas.", "Classical"),
    ("Discovering the stories within classical symphonies.", "Classical"),
    ("Capturing the essence of elegance with classical strings.", "Classical"),
    ("Reflecting on life's grandeur through classical opuses.", "Classical"),
    ("Enjoying a lazy Sunday morning.", "Acoustic"),
    ("Overcoming obstacles and feeling triumphant.", "Rock"),
    ("Reflecting on the beauty of nature.", "Folk"),
    ("Connecting with nature's serenity through folk melodies.", "Folk"),
    ("Embracing the warmth of acoustic folk tunes.", "Folk"),
    ("Finding comfort in the storytelling of folk music.", "Folk"),
    ("Reflecting on life's journey with heartfelt folk ballads.", "Folk"),
    ("Dancing like nobody's watching to lively folk beats.", "Folk"),
    ("Needing some energy to tackle household chores.", "Pop"),
    ("Longing for a tropical vacation and relaxation.", "Reggae"),
    ("Dealing with a case of the Monday blues.", "Blues"),
    ("Ready to conquer the world and make a difference.", "Hip-hop"),
    ("Exploring new ideas and seeking inspiration.", "Electronic"),
    ("Finding joy in simple moments and laughter.", "Folk"),
    ("Contemplating the mysteries of the universe.", "Classical"),
    ("Chasing dreams and embracing the journey.", "Pop"),
    ("Embarking on a global musical journey with world music.", "World"),
    ("Exploring diverse cultures through the rhythms of world music.", "World"),
    ("Savoring the beauty of musical traditions from around the world.", "World"),
    ("Reflecting on unity and diversity through world music melodies.", "World"),
    ("Immersing myself in the vibrant tapestry of world rhythms.", "World"),
    ("Capturing the essence of connection through world music tunes.", "World"),
    ("Embracing the spirit of exploration in world soundscapes.", "World"),
    ("Discovering the stories and histories carried by world melodies.", "World"),
    ("Feeling the heartbeat of humanity in the rhythms of world music.", "World"),
    ("Reflecting on the changing seasons of life.", "Acoustic"),
    ("Dancing like nobody's watching and having fun.", "Pop"),
    ("Rediscovering the magic of music's golden oldies.", "Oldies"),
    ("Journeying back in time with classic oldies tunes.", "Oldies"),
    ("Finding comfort in the nostalgia of oldies melodies.", "Oldies"),
    ("Reflecting on the timeless beauty of oldies ballads.", "Oldies"),
    ("Immersing myself in the timeless classics of yesteryears.", "Oldies"),
    ("Capturing the essence of love and memories through oldies hits.", "Oldies"),
    ("Embracing the charm and simplicity of oldies soundscapes.", "Oldies"),
    ("Discovering the stories and emotions woven into oldies songs.", "Oldies"),
    ("Feeling the heartbeat of generations through oldies rhythms.", "Oldies"),
    ("Finding solace in the melodies that heal.", "Classical"),
    ("Savoring the taste of good food and company.", "Jazz"),
    ("Embracing solitude and self-discovery.", "Indie"),
    ("Feeling the beat and letting loose on the dancefloor.", "EDM"),
    ("Connecting with the rhythm of life's heartbeat.", "World"),
    ("Rekindling old friendships and making memories.", "Oldies"),
    ("Unwinding with mellow tunes and relaxation.", "Chill"),
    ("Facing challenges with courage and determination.", "Rock"),
    ("Laughing at life's quirks and oddities.", "Comedy"),
    ("Dreaming big and setting goals for the future.", "Pop"),
    ("Exploring the universe within and without.", "Ambient"),
    ("Diving into the tranquil ocean of ambient sounds.", "Ambient"),
    ("Embracing the ethereal atmosphere of ambient music.", "Ambient"),
    ("Savoring the stillness of ambient soundscapes.", "Ambient"),
    ("Reflecting on life's mysteries with ambient harmonies.", "Ambient"),
    ("Losing myself in the serenity of ambient melodies.", "Ambient"),
    ("Capturing the essence of tranquility through ambient tunes.", "Ambient"),
    ("Finding solace in the immersive world of ambient music.", "Ambient"),
    ("Discovering new dimensions in ambient sonic explorations.", "Ambient"),
    ("Meditating to the soothing vibrations of ambient compositions.", "Ambient"),
    ("Creating art and expressing oneself through music.", "Indie"),
    ("Reviving memories with familiar melodies.", "Nostalgia"),
    ("Finding comfort in the embrace of loved ones.", "Ballad"),
    ("Energized and ready to conquer the day.", "Pop"),
    ("Embracing the night and its enchanting mysteries.", "Electronic"),
    ("Navigating life's twists and turns with grace.", "Jazz"),
    ("Cultivating inner peace and mindfulness.", "Meditation"),
    ("Celebrating love and the beauty of human connections.", "Romantic"),
    ("Seeking adventure in the great outdoors.", "Folk"),
    ("Immersing myself in the heartfelt and nostalgic country rhythms.", "Country"),
    ("Capturing the essence of home, love, and longing in country compositions.", "Country"),
    ("Embracing the down-to-earth and genuine atmosphere of country soundscapes.", "Country"),
    ("Discovering the spirit of resilience and hope that resonates in country music.", "Country"),
    ("Feeling the heartbeat of genuine connection and storytelling through country rhythms.", "Country"),
    ("Meditating to the comforting and soulful melodies that evoke memories of home.", "Country"),
    ("Two-stepping to the twangy tunes of country that tell stories close to the heart.", "Country"),
    ("Creating moments of reflection and nostalgia with country melodies.", "Country"),
    ("Embracing vulnerability and authentic self-expression.", "Indie"),
    ("Uplifting spirits and spreading positivity.", "Pop"),
    ("Finding strength in unity and togetherness.", "World"),
    ("Appreciating the beauty of cultural diversity.", "Fusion"),
    ("Exploring the cosmos of imagination and creativity.", "Experimental"),
    ("Transforming challenges into opportunities for growth.", "Motivational"),
    ("Appreciating the stillness and serenity of the night.", "Ambient"),
    ("Celebrating milestones and achievements.", "Victory"),
    ("Finding solace in the embrace of nature.", "Nature"),
    ("Exploring the depths of the ocean of emotions.", "Deep House"),
    ("Feeling the pulse of the city and its energy.", "Urban"),
    ("Diving into the pages of a captivating story.", "Soundtrack"),
    ("Embracing the freedom of expression with indie melodies.", "Indie"),
    ("Celebrating individuality and embracing quirks.", "Indie"),
    ("Embarking on a journey through electronic beats and rhythms.", "Electronic"),
    ("Dancing to the vibrant energy of electronic music.", "Electronic"),
    ("Exploring futuristic sounds in electronic compositions.", "Electronic"),
    ("Unwinding to the pulsating beats of electronic melodies.", "Electronic"),
    ("Capturing the essence of innovation through electronic tunes.", "Electronic"),
    ("Savoring the fusion of technology and art in electronic music.", "Electronic"),
    ("Embracing the immersive world of electronic soundscapes.", "Electronic"),
    ("Discovering the endless possibilities of electronic creativity.", "Electronic"),
    ("Feeling the heartbeat of the digital age through electronic rhythms.", "Electronic"),
    ("Finding joy in the simple pleasures of life.", "Feel Good"),
    ("Embracing change and adapting with resilience.", "Pop"),
    ("Exploring the mysteries of the universe through music.", "Electronic"),
    ("Savoring the quiet moments of a rainy day.", "Acoustic"),
    ("Finding solace in the melodies of the night.", "Ambient"),
    ("Embracing the rhythm of the urban jungle.", "Hip-hop"),
    ("Celebrating the beauty of diversity and unity.", "World"),
    ("Nurturing the soul with soothing jazz melodies.", "Jazz"),
    ("Dancing under the stars to lively Latin beats.", "Latin"),
    ("Reflecting on life's journey through classic rock.", "Rock"),
    ("Chasing dreams and chasing sunsets.", "Indie"),
    ("Finding strength in the midst of life's storms.", "Blues"),
    ("Unwinding with mellow folk tunes and warm tea.", "Folk"),
    ("Elevating the spirit with soulful R&B melodies.", "R&B"),
    ("Exploring the depths of self-discovery through indie melodies.", "Indie"),
    ("Finding solace in the intimate sounds of indie music.", "Indie"),
    ("Embracing authenticity and vulnerability through indie tunes.", "Indie"),
    ("Indulging in the indie vibe for a soulful escape.", "Indie"),
    ("Feeling the heartbeat of life through indie rhythms.", "Indie"),
    ("Embracing the joy of life with energetic pop anthems.", "Pop"),
    ("Exploring the enigma of time with experimental sounds.", "Experimental"),
    ("Nostalgic for the songs that colored my youth.", "Oldies"),
    ("Expressing raw emotions through indie ballads.", "Indie"),
    ("Finding inspiration in the beauty of nature's symphony.", "Classical"),
    ("Grooving to funky beats and contagious rhythm.", "Funk"),
    ("Uplifting spirits with motivational hip-hop tracks.", "Hip-hop"),
    ("Navigating the labyrinth of emotions with EDM.", "EDM"),
    ("Feeling the pulse of the city through urban beats.", "Urban"),
    ("Capturing life's essence in the melodies of a soundtrack.", "Soundtrack"),
    ("Reviving the soul with soulful reggae vibes.", "Reggae"),
    ("Transcending the mundane with ethereal ambient tunes.", "Ambient"),
    ("Embracing the spirit of rebellion through punk rock.", "Rock"),
    ("Finding balance and serenity through meditation music.", "Meditation"),
    ("Merging cultures and sounds through fusion melodies.", "Fusion"),
    ("Rediscovering forgotten memories in old-school tunes.", "Nostalgia"),
    ("Embracing the power of dance and electronic beats.", "Electronic"),
    ("Finding courage in the midst of adversity with metal.", "Metal"),
    ("Savoring the moments of laughter and joy.", "Feel Good"),
    ("Creating a soundtrack for everyday moments.", "Acoustic"),
    ("Journeying through imaginary landscapes with orchestral music.", "Classical"),
    ("Seeking solace in the embrace of acoustic folk.", "Folk"),
    ("Tapping into the power of nostalgia through old classics.", "Oldies"),
    ("Exploring the depths of emotions through deep house beats.", "Deep House"),
    ("Embracing the essence of summertime with reggae tunes.", "Reggae"),
    ("Feeling the heartbeat of nature in world music.", "World"),
    ("Awakening the senses with energetic pop rock.", "Pop"),
    ("Getting lost in the improvisational world of jazz melodies.", "Jazz"),
    ("Dancing to the vibrant energy of jazz rhythms.", "Jazz"),
    ("Savoring the soulful harmonies of jazz compositions.", "Jazz"),
    ("Reflecting on life's complexities with jazz tunes.", "Jazz"),
    ("Immersing myself in the rich history of jazz music.", "Jazz"),
    ("Capturing the essence of emotion through jazz improvisations.", "Jazz"),
    ("Embracing the sophistication of jazz soundscapes.", "Jazz"),
    ("Discovering the artistry of jazz musicians and their stories.", "Jazz"),
    ("Feeling the heartbeat of the city through jazz rhythms.", "Jazz"),
    ("Navigating the crossroads of life with indie melodies.", "Indie"),
    ("Journeying through the heartland with the timeless melodies of country music.", "Country"),
    ("Embracing the authenticity and storytelling of country's rich traditions.", "Country"),
    ("Savoring the melodies that capture the essence of rural life and values.", "Country"),
    ("Reflecting on life's simplicity and complexities within country tunes.", "Country"),
    ("Cultivating self-love and acceptance through R&B.", "R&B"),
    ("Escaping to a world of fantasy through fantasy soundtracks.", "Soundtrack"),
    ("Unwinding after a long day with soothing jazz.", "Jazz"),
    ("Reflecting on the joy and movement within the vibrant rhythms of dance tunes.", "Dance"),
    ("Immersing myself in the euphoric and uplifting dance rhythms.", "Dance"),
    ("Capturing the essence of celebration and unity in dance compositions.", "Dance"),
    ("Embracing the pulsating and euphoric atmosphere of dance soundscapes.", "Dance"),
    ("Discovering the universal language of dance that transcends boundaries.", "Dance"),
    ("Finding hope and strength in soulful ballads.", "Soul"),
    ("Chasing the sun and dancing in its golden rays.", "Dance"),
    ("Rekindling memories with classic country tunes.", "Country"),
    ("Reflecting on love's journey through timeless ballads.", "Ballad"),
    ("Questioning reality and existence through alternative sounds.", "Alternative"),
    ("Finding solace in the unconventional rhythms of experimental music.", "Experimental"),
    ("Embracing the complexity of life with experimental beats.", "Experimental"),
    ("Journeying through abstract landscapes with alternative melodies.", "Alternative"),
    ("Exploring the fringes of creativity through experimental sounds.", "Experimental"),
    ("Seeking refuge in the avant-garde realm of alternative rock.", "Alternative"),
    ("Elevating the spirit with experimental electronic compositions.", "Experimental"),
    ("Embracing the simplicity of life with acoustic folk melodies.", "Folk"),
    ("Finding solace in the gentle strumming of folk guitars.", "Folk"),
    ("Feeling the power of rock and roll coursing through my veins.", "Rock"),
    ("Rocking out to the energetic anthems of the rock genre.", "Rock"),
    ("Channeling emotions through the raw energy of rock music.", "Rock"),
    ("Reflecting on life's highs and lows with rock melodies.", "Rock"),
    ("Immersing myself in the timeless classics of rock history.", "Rock"),
    ("Capturing the essence of rebellion through rock tunes.", "Rock"),
    ("Embracing the electric intensity of rock soundscapes.", "Rock"),
    ("Discovering the soul-stirring messages within rock lyrics.", "Rock"),
    ("Feeling the heartbeat of the crowd at a live rock concert.", "Rock"),
    ("Capturing the essence of nostalgia through folk harmonies.", "Folk"),
    ("Diving into the unknown with alternative indie tunes.", "Alternative"),
    ("Breaking free from convention through experimental sonic explorations.", "Experimental"),
    ("Transcending boundaries and norms with alternative vibes.", "Alternative"),
    ("Venturing into the uncharted territory of experimental music.", "Experimental"),
    ("Finding beauty in chaos through experimental soundscapes.", "Experimental"),
    ("Embracing the enigma of life through alternative melodies.", "Alternative"),
    ("Navigating the intricacies of emotions with experimental beats.", "Experimental"),
    ("Capturing the essence of love, longing, and sentiment in ballad compositions.", "Ballad"),
    ("Reflecting on life's most profound moments through the melodies of ballads.", "Ballad"),
    ("Embracing the depth of human emotion and connection within ballad music.", "Ballad"),
    ("Finding solace and understanding in the heartfelt lyrics of ballad melodies.", "Ballad"),
    ("Meditating on the beauty of vulnerability and honesty conveyed by ballads.", "Ballad"),
    ("Navigating the journey of the heart through the tender melodies of ballads.", "Ballad"),
    ("Dancing through the emotions with the delicate rhythms of ballad tunes.", "Ballad"),
    ("Losing myself in the mesmerizing beats of deep house music.", "Deep House"),
    ("Embracing the soulful energy of deep house rhythms.", "Deep House"),
    ("Savoring the chill vibes and melodies of deep house tunes.", "Deep House"),
    ("Reflecting on life's mysteries through deep house soundscapes.", "Deep House"),
    ("Immersing myself in the enchanting atmosphere of deep house melodies.", "Deep House"),
    ("Capturing the essence of relaxation and groove in deep house compositions.", "Deep House"),
    ("Immersing myself in the vibrant and dynamic funk rhythms.", "Funk"),
    ("Capturing the essence of rhythm and soul in funk compositions.", "Funk"),
    ("Embracing the electric and spirited atmosphere of funk soundscapes.", "Funk"),
    ("Discovering the power of music to bring the funk and get me moving.", "Funk"),
    ("Feeling the heartbeat of the groove and rhythm through funk rhythms.", "Funk"),
    ("Embracing the nightlife and rhythm of the city with deep house beats.", "Deep House"),
    ("Discovering a world of electronic emotions within deep house tracks.", "Deep House"),
    ("Feeling the heartbeat of the dancefloor through deep house rhythms.", "Deep House"),
    ("Dancing to the hypnotic flow of deep house music.", "Deep House"),
    ("Meditating to the soothing vibrations of deep house harmonies.", "Deep House"),
    ("Moving to the rhythm of life with electrifying dance music.", "Dance"),
    ("Embracing the energy and freedom of dance through lively tunes.", "Dance"),
    ("Savoring the infectious melodies that compel me to hit the dance floor.", "Dance"),
    ("Feeling the heartbeat of connection and joy through dance rhythms.", "Dance"),
    ("Meditating to the invigorating and rhythmic melodies that ignite my spirit.", "Dance"),
    ("Expressing myself and finding release through the power of dance music.", "Dance"),
    ("Creating moments of pure exhilaration and movement with dance melodies.", "Dance"),
    ("Reimagining reality through the lens of alternative rock.", "Alternative"),
    ("Weaving tales of introspection with experimental compositions.", "Experimental"),
    ("Embracing the spirit of rebellion through alternative anthems.", "Alternative"),
    ("Meditating to the funky and soulful melodies that uplift the spirit.", "Funk"),
    ("Dancing to the funk-filled beats that celebrate the joy of life.", "Funk"),
    ("Creating an atmosphere of fun and excitement with funky melodies.", "Funk"),
    ("Channeling raw emotions and energy through the intensity of metal music.", "Metal"),
    ("Embracing the power and catharsis of metal in its diverse forms.", "Metal"),
    ("Savoring the melodies that push the boundaries of sonic expression.", "Metal"),
    ("Reflecting on life's complexities through the heavy rhythms of metal tunes.", "Metal"),
    ("Immersing myself in the aggressive and powerful metal rhythms.", "Metal"),
    ("Capturing the essence of rebellion and authenticity in metal compositions.", "Metal"),
    ("Embracing the dynamic and electrifying atmosphere of metal soundscapes.", "Metal"),
    ("Discovering the fierce spirit and unity within the metal community.", "Metal"),
    ("Feeling the heartbeat of strength and resilience through metal rhythms.", "Metal"),
    ("Embracing the gentle melodies of acoustic guitars.", "Acoustic"),
    ("Finding comfort in the warmth of acoustic ballads.", "Acoustic"),
    ("Savoring the simplicity of acoustic folk tunes.", "Acoustic"),
    ("Reflecting on life's moments with acoustic harmonies.", "Acoustic"),
    ("Unwinding to the soothing sounds of acoustic melodies.", "Acoustic"),
    ("Capturing the essence of emotion through acoustic notes.", "Acoustic"),
    ("Creating a cinematic experience with captivating soundtrack melodies.", "Soundtrack"),
    ("Diving into imaginary worlds through the enchanting notes of soundtracks.", "Soundtrack"),
    ("Savoring the emotions of stories told through movie soundtrack music.", "Soundtrack"),
    ("Reflecting on life's moments with the evocative power of soundtracks.", "Soundtrack"),
    ("Grooving to the laid-back rhythms of reggae beats.", "Reggae"),
    ("Embracing the positive vibes of reggae music.", "Reggae"),
    ("Savoring the soulful harmonies of reggae melodies.", "Reggae"),
    ("Celebrating love's magic with melodies that touch the heart and soul.", "Romantic"),
    ("Embracing the tender and passionate vibes of romantic music.", "Romantic"),
    ("Savoring the melodies that speak of affection and longing.", "Romantic"),
    ("Reflecting on the beauty of human connection through romantic tunes.", "Romantic"),
    ("Immersing myself in the emotion and vulnerability of romantic rhythms.", "Romantic"),
    ("Capturing the essence of intimacy and desire in romantic compositions.", "Romantic"),
    ("Embracing the sentimental and enchanting atmosphere of romantic soundscapes.", "Romantic"),
    ("Laughing at life's quirks and oddities through comedic musical experiences.", "Comedy"),
    ("Embracing the lighthearted and humorous vibes of comedy music.", "Comedy"),
    ("Savoring the melodies that tickle my funny bone and bring joy.", "Comedy"),
    ("Reflecting on the amusing side of life while enjoying comedy tunes.", "Comedy"),
    ("Grooving to the infectious and funky rhythms that make me move.", "Funk"),
    ("Embracing the soulful and energetic vibes of funk music.", "Funk"),
    ("Savoring the groovy melodies that ignite the dance floor.", "Funk"),
    ("Reflecting on the timeless and irresistible funk within the tunes.", "Funk"),
    ("Meditating to the intense and passionate melodies that fuel my fire.", "Metal"),
    ("Headbanging to the roaring melodies of metal that speak to my soul.", "Metal"),
    ("Creating an outlet for expression and release through metal music.", "Metal"),
    ("Immersing myself in the comical narratives and playful rhythms.", "Comedy"),
    ("Capturing the essence of humor and wit within comedic compositions.", "Comedy"),
    ("Embracing the whimsical and entertaining atmosphere of comedy soundscapes.", "Comedy"),
    ("Discovering the power of music to bring a smile to my face with comedic tracks.", "Comedy"),
    ("Feeling the heartbeat of joy and laughter through comedic rhythms.", "Comedy"),
    ("Immersing myself in the dynamic and vibrant universe of EDM.", "EDM"),
    ("Unveiling emotions and stories through the timeless allure of ballads.", "Ballad"),
    ("Letting the emotions flow with the heart-touching melodies of ballads.", "Ballad"),
    ("Immersing myself in the tender and soul-stirring narratives of ballads.", "Ballad"),
    ("Savoring the intimate and emotive stories told by the melodies of ballads.", "Ballad"),
    ("Connecting with the soul of the party through the beats of EDM.", "EDM"),
    ("Letting go and dancing to the pulsating rhythm of electronic music.", "EDM"),
    ("Feeling the rush of euphoria as the EDM beats take over the senses.", "EDM"),
    ("Navigating the dancefloor with the infectious energy of EDM tunes.", "EDM"),
    ("Embracing the electric vibes and boundless energy of EDM melodies.", "EDM"),
    ("Meditating to the cheerful and comedic melodies that brighten my day.", "Comedy"),
    ("Dancing to the rhythm of laughter and happiness with comedy music.", "Comedy"),
    ("Creating moments of lightness with the comedic melodies that lift my spirits.", "Comedy"),
    ("Discovering the stories of love and devotion within romantic tracks.", "Romantic"),
    ("Feeling the heartbeat of connection and tenderness through romantic rhythms.", "Romantic"),
    ("Meditating to the gentle and heartwarming melodies that celebrate love.", "Romantic"),
    ("Dancing to the rhythm of love's journey with romantic music.", "Romantic"),
    ("Creating unforgettable moments with the romantic melodies that sweep me away.", "Romantic"),
    ("Reflecting on life's simplicity through reggae tunes.", "Reggae"),
    ("Immersing myself in the carefree spirit of reggae rhythms.", "Reggae"),
    ("Capturing the essence of unity and love in reggae compositions.", "Reggae"),
    ("Embracing the sunshine and warmth of reggae soundscapes.", "Reggae"),
    ("Discovering the messages of hope and change within reggae lyrics.", "Reggae"),
    ("Feeling the heartbeat of the island culture through reggae rhythms.", "Reggae"),
    ("Dancing to the rhythms of reggae that transcend boundaries.", "Reggae"),
    ("Capturing the essence of drama and adventure in soundtrack compositions.", "Soundtrack"),
    ("Embracing the magic of soundtracks that transport me to different realms.", "Soundtrack"),
    ("Discovering the hidden emotions within the melodies of movie soundtracks.", "Soundtrack"),
    ("Feeling the heartbeat of scenes through the rhythms of soundtrack tunes.", "Soundtrack"),
    ("Reliving memorable movie moments through the melodies of soundtracks.", "Soundtrack"),
    ("Immersing myself in the artistry of composers through soundtrack soundscapes.", "Soundtrack"),
    ("Embracing the authenticity of acoustic music.", "Acoustic"),
    ("Discovering the power of storytelling in acoustic songs.", "Acoustic"),
    ("Finding serenity in acoustic symphonies.", "Acoustic"),
    ("Discovering new dimensions of sound with experimental fusion.", "Experimental"),
    ("Feeling the soulful depths of blues music resonate within me.", "Blues"),
    ("Embracing the emotional journey of blues melodies.", "Blues"),
    ("Savoring the raw storytelling of blues lyrics.", "Blues"),
    ("Reflecting on life's trials and tribulations through blues tunes.", "Blues"),
    ("Immersing myself in the heartfelt expressions of blues rhythms.", "Blues"),
    ("Capturing the essence of authenticity and emotion in blues compositions.", "Blues"),
    ("Embracing the timeless charm and honesty of blues soundscapes.", "Blues"),
    ("Celebrating the joy of life through the exhilarating sounds of Latin music.", "Latin"),
    ("Embracing the vivacious spirit of Latin beats and their fiery allure.", "Latin"),
    ("Connecting with the heart and soul of Latin culture through its music.", "Latin"),
    ("Letting loose and surrendering to the intoxicating rhythms of Latin tunes.", "Latin"),
    ("Diving into the colorful and passionate world of Latin melodies.", "Latin"),
    ("Savoring the flavors of Latin music that transport me to distant lands.", "Latin"),
    ("Capturing the essence of celebration and unity in the vibrant beats of Latin tunes.", "Latin"),
    ("Discovering the power of music to touch the soul and ignite emotions.", "Soul"),
    ("Feeling the heartbeat of empathy and connection through soul rhythms.", "Soul"),
    ("Meditating to the soothing and soulful melodies that speak to the heart.", "Soul"),
    ("Dancing to the groove of life with the soul-stirring tunes that move me.", "Soul"),
    ("Creating moments of introspection and solace with soulful melodies.", "Soul"),
    ("Discovering the cathartic release within blues guitar solos.", "Blues"),
    ("Feeling the heartbeat of human experience through blues rhythms.", "Blues"),
    ("Listening to the echoes of history in the melodies of blues music.", "Blues"),
    ("Finding comfort in the unconventional melodies of alternative.", "Alternative"),
    ("Diving into the soulful depths of the blues and letting its emotions wash over me.", "Blues"),
    ("Getting into the groove with the beats of hip-hop music.", "Hip-hop"),
    ("Embracing the rhythm and flow of hip-hop melodies.", "Hip-hop"),
    ("Savoring the poetic storytelling of hip-hop lyrics.", "Hip-hop"),
    ("Reflecting on life's realities through the messages of hip-hop songs.", "Hip-hop"),
    ("Immersing myself in the cultural expressions of hip-hop rhythms.", "Hip-hop"),
    ("Capturing the essence of empowerment and self-expression in hip-hop.", "Hip-hop"),
    ("Embracing the urban spirit and creativity of hip-hop soundscapes.", "Hip-hop"),
    ("Exploring the harmonious fusion of cultures through music that transcends boundaries.", "Fusion"),
    ("Embracing the blending of diverse musical elements in fusion compositions.", "Fusion"),
    ("Savoring the unique and eclectic soundscapes created by fusion melodies.", "Fusion"),
    ("Reflecting on the beauty of unity in diversity within fusion tunes.", "Fusion"),
    ("Immersing myself in the global rhythms and harmonies of fusion music.", "Fusion"),
    ("Capturing the essence of cultural exchange through fusion soundscapes.", "Fusion"),
    ("Embracing the fluidity and creativity of musical fusion.", "Fusion"),
    ("Discovering the power of music to bring different worlds together in fusion tracks.", "Fusion"),
    ("Feeling the heartbeat of cross-cultural connections through fusion rhythms.", "Fusion"),
    ("Dancing to the rhythm of fusion that celebrates the diversity of human expression.", "Fusion"),
    ("Meditating to the soothing fusion melodies that harmonize mind and soul.", "Fusion"),
    ("Diving into the electrifying world of EDM and its energetic rhythms.", "EDM"),
    ("Riding the waves of electronic beats and pulsating rhythms in EDM.", "EDM"),
    ("Elevating the spirit with the high-energy dance beats of EDM.", "EDM"),
    ("Synchronizing my heartbeat with the electrifying rhythm of EDM.", "EDM"),
    ("Raving to the euphoric melodies that define the essence of EDM.", "EDM"),
    ("Discovering the voices of change and resilience within hip-hop tracks.", "Hip-hop"),
    ("Feeling the heartbeat of the streets and cities through hip-hop beats.", "Hip-hop"),
    ("Dancing to the beats of hip-hop that spark a sense of freedom.", "Hip-hop"),
    ("Diving into the serene ocean of meditation music to find inner peace.", "Meditation"),
    ("Embracing the tranquil melodies that guide me on my meditation journey.", "Meditation"),
    ("Savoring the calming vibrations of meditation music that soothe the mind.", "Meditation"),
    ("Unveiling fragments of the past in the evocative stories told by nostalgia.", "Nostalgia"),
    ("Embracing the comforting embrace of nostalgia through its tender tunes.", "Nostalgia"),
    ("Feeling the echoes of forgotten moments in the gentle melodies of nostalgia.", "Nostalgia"),
    ("Navigating the sea of memories with the guiding star of nostalgia's melodies.", "Nostalgia"),
    ("Capturing the essence of bygone days in the tender embrace of nostalgia.", "Nostalgia"),
    ("Meditating on the whispers of the past through the melodies of nostalgia.", "Nostalgia"),
    ("Dancing through the corridors of time with the melodies that evoke nostalgia.", "Nostalgia"),
    ("Reflecting on my inner world as I immerse myself in meditation soundscapes.", "Meditation"),
    ("Immersing myself in the healing frequencies of meditation melodies.", "Meditation"),
    ("Capturing the essence of mindfulness and relaxation through meditation compositions.", "Meditation"),
    ("Embracing the stillness and clarity of mind that meditation music brings.", "Meditation"),
    ("Discovering the power of sound to create a meditative sanctuary within.", "Meditation"),
    ("Feeling the heartbeat of serenity and tranquility through meditation rhythms.", "Meditation"),
    ("Meditating to the gentle and meditative melodies that restore balance.", "Meditation"),
    ("Merging with the cosmic flow through meditation music that elevates the soul.", "Meditation"),
    ("Capturing the essence of the bizarre in experimental music.", "Experimental"),
    ("Grooving to the smooth rhythms of R&B melodies.", "R&B"),
    ("Embracing the sultry and soulful vibes of R&B music.", "R&B"),
    ("Savoring the emotional depth of R&B lyrics.", "R&B"),
    ("Reflecting on love, relationships, and emotions through R&B tunes.", "R&B"),
    ("Immersing myself in the sensuality and passion of R&B rhythms.", "R&B"),
    ("Capturing the essence of heartache and joy in R&B compositions.", "R&B"),
    ("Dancing to the lively and passionate rhythms of Latin music.", "Latin"),
    ("Swaying to the infectious beats of Latin melodies that ignite the soul.", "Latin"),
    ("Immersing myself in the vibrant and dynamic world of Latin rhythms.", "Latin"),
    ("Feeling the heat of Latin music's energy and zest for life.", "Latin"),
    ("Exploring the rich cultural tapestry woven by the melodies of Latin tunes.", "Latin"),
    ("Embracing the contemporary sounds and narratives of R&B soundscapes.", "R&B"),
    ("Lifting my spirits with feel-good tunes that spread joy.", "Feel Good"),
    ("Embracing the positivity and happiness of feel-good music.", "Feel Good"),
    ("Savoring the melodies that put a smile on my face.", "Feel Good"),
    ("Reflecting on life's simple pleasures through feel-good rhythms.", "Feel Good"),
    ("Immersing myself in the upbeat and energetic feel-good melodies.", "Feel Good"),
    ("Capturing the essence of good vibes and positivity in feel-good compositions.", "Feel Good"),
    ("Embracing the carefree spirit of feel-good soundscapes.", "Feel Good"),
    ("Connecting with the urban energy and attitude of urban music.", "Urban"),
    ("Embracing the rhythm and flow of urban beats.", "Urban"),
    ("Savoring the authenticity and stories of urban lyrics.", "Urban"),
    ("Reflecting on city life and experiences through urban tunes.", "Urban"),
    ("Immersing myself in the cultural expressions of urban rhythms.", "Urban"),
    ("Capturing the essence of streetwise wisdom and resilience in urban compositions.", "Urban"),
    ("Embracing the diversity and creativity of urban soundscapes.", "Urban"),
    ("Discovering the voices and perspectives of urban communities within tracks.", "Urban"),
    ("Feeling the heartbeat of the city through the rhythms of urban music.", "Urban"),
    ("Dancing to the beats of urban music that resonate with urban life.", "Urban"),
    ("Meditating to the urban sounds that capture the pulse of modern living.", "Urban"),
    ("Discovering the power of music to uplift and inspire with feel-good tracks.", "Feel Good"),
    ("Feeling the heartbeat of joy and optimism through feel-good rhythms.", "Feel Good"),
    ("Unwinding with mellow tunes that create a serene and relaxed atmosphere.", "Chill"),
    ("Embracing the calming and soothing vibes of chill music.", "Chill"),
    ("Savoring the laid-back rhythms that help me find my zen.", "Chill"),
    ("Reflecting on life's simple pleasures while listening to chill tunes.", "Chill"),
    ("Immersing myself in the peaceful melodies that invite tranquility.", "Chill"),
    ("Capturing the essence of relaxation and escape in chill compositions.", "Chill"),
    ("Embracing the cozy and comforting feeling of chill soundscapes.", "Chill"),
    ("Feeling the energy of pop music radiate positivity and excitement.", "Pop"),
    ("Embracing the catchy melodies and vibrant rhythms of pop tunes.", "Pop"),
    ("Celebrating each victory in life with triumphant melodies.", "Victory"),
    ("Embracing the exhilarating feeling of success through victory music.", "Victory"),
    ("Savoring the empowering rhythms that accompany moments of triumph.", "Victory"),
    ("Reflecting on the journey of overcoming challenges with victory tunes.", "Victory"),
    ("Immersing myself in the melodies of victory that inspire perseverance.", "Victory"),
    ("Immersing myself in the serene melodies that mirror the beauty of nature.", "Nature"),
    ("Embracing the tranquility and wonder of nature through music.", "Nature"),
    ("Savoring the harmonious rhythms that echo the symphony of the natural world.", "Nature"),
    ("Reflecting on the majesty of landscapes through melodies inspired by nature.", "Nature"),
    ("Capturing the essence of peace and renewal within nature-inspired compositions.", "Nature"),
    ("Embracing the interconnectedness of life and music through nature soundscapes.", "Nature"),
    ("Exploring the uncharted realms of thought and sound with alternative melodies.", "Alternative"),
    ("Discovering the magic of earth's wonders in melodies that mimic nature.", "Nature"),
    ("Drawing strength from motivational melodies that ignite my spirit.", "Motivational"),
    ("Embracing the power of music to uplift and inspire through motivational tunes.", "Motivational"),
    ("Savoring the encouraging rhythms that propel me forward with motivation.", "Motivational"),
    ("Reflecting on the path to success guided by motivational melodies.", "Motivational"),
    ("Discovering the power of music to create a chill ambiance in any setting.", "Chill"),
    ("Feeling the heartbeat of serenity and balance through chill rhythms.", "Chill"),
    ("Meditating to the gentle and calming melodies that quiet the mind.", "Chill"),
    ("Finding solace and rejuvenation in the melodies of chill music.", "Chill"),
    ("Creating a space of tranquility with the soul-soothing vibes of chill tunes.", "Chill"),
    ("Immersing myself in the melodies of motivation that light the way.", "Motivational"),
    ("Capturing the essence of ambition and drive within motivational compositions.", "Motivational"),
    ("Embracing the unwavering spirit of motivation that resonates in soundscapes.", "Motivational"),
    ("Discovering the potential for greatness within through motivational tracks.", "Motivational"),
    ("Rediscovering the moments of the past through nostalgic melodies.", "Nostalgia"),
    ("Reflecting on cherished memories with the heartwarming tunes of nostalgia.", "Nostalgia"),
    ("Journeying back in time with the melodies that echo nostalgia's embrace.", "Nostalgia"),
    ("Savoring the bittersweet emotions that nostalgia's melodies bring to life.", "Nostalgia"),
    ("Connecting with the depth of human emotions through soulful melodies.", "Soul"),
    ("Embracing the passion and authenticity of soul music.", "Soul"),
    ("Savoring the melodies that resonate with the core of my being.", "Soul"),
    ("Reflecting on life's journey with the soulful stories within the tunes.", "Soul"),
    ("Immersing myself in the heartfelt and emotive soul rhythms.", "Soul"),
    ("Capturing the essence of vulnerability and love within soul compositions.", "Soul"),
    ("Embracing the warm and timeless atmosphere of soul soundscapes.", "Soul"),
    ("Feeling the heartbeat of determination and resilience in motivational rhythms.", "Motivational"),
    ("Meditating to the empowering and uplifting melodies that fuel my motivation.", "Motivational"),
    ("Uplifting my spirits and fueling my dreams with motivational music.", "Motivational"),
    ("Transforming challenges into stepping stones through motivational sounds.", "Motivational"),
    ("Feeling the heartbeat of the planet through nature rhythms that connect us all.", "Nature"),
    ("Meditating to the gentle and soothing melodies that bring me closer to nature.", "Nature"),
    ("Dancing to the rhythm of the natural world as expressed through music.", "Nature"),
    ("Finding solace and serenity in the melodies of nature's embrace.", "Nature"),
    ("Celebrating the beauty and grandeur of nature through musical landscapes.", "Nature"),
    ("Capturing the essence of achievement and conquest in victory compositions.", "Victory"),
    ("Embracing the triumphant spirit that resides within victory soundscapes.", "Victory"),
    ("Discovering the courage and determination to win in victory tracks.", "Victory"),
    ("Feeling the heartbeat of personal growth and success through victory rhythms.", "Victory"),
    ("Marching to the rhythm of victory that echoes resilience and accomplishment.", "Victory"),
    ("Meditating to the empowering victory melodies that fuel motivation.", "Victory"),
    ("Conquering challenges and celebrating with victorious music.", "Victory"),
    ("Savoring the infectious beats that get me dancing to pop music.", "Pop"),
    ("Dancing to the irresistible and infectious beats of feel-good tunes.", "Feel Good"),
    ("Meditating to the soothing and optimistic feel-good melodies.", "Feel Good"),
    ("Discovering the stories of love and vulnerability within R&B tracks.", "R&B"),
    ("Feeling the heartbeat of human connection through R&B rhythms.", "R&B"),
    ("Dancing to the smooth and seductive grooves of R&B music.", "R&B"),
    ("Meditating to the soothing and soul-healing vibes of R&B melodies.", "R&B"),
    ("Finding solace in the unconventional rhythms of alternative music.", "Alternative"),
    ("Embracing the complexity of life with alternative beats.", "Alternative"),
    ("Exploring the fringes of creativity through alternative melodies.", "Alternative")

]


# Creating a DataFrame
df = pd.DataFrame(data, columns=["Message", "Genre"])

# Saving the DataFrame as a CSV file
df.to_csv("music_recommendation_dataset.csv", index=False)

# %%
data = pd.read_csv('/content/music_recommendation_dataset.csv')

# %%
data.head()
# Out:
#                                              Message      Genre
# 0            Excited about starting a new adventure.        Pop
# 1           Feeling nostalgic for the good old days.     Oldies
# 2         Trying to focus and be productive at work.  Classical
# 3  Diving into the timeless beauty of classical c...  Classical
# 4  Journeying through history with the elegance o...  Classical

# %%
df.duplicated().value_counts()
# Out:
# False    494
# dtype: int64

# %%
# Count the occurrences of each genre
genre_counts = df["Genre"].value_counts()
genre_counts
# Out:
# Pop             13
# Urban           13
# Country         13
# Fusion          13
# Experimental    13
# Motivational    13
# Victory         13
# Nature          13
# Deep House      13
# Soundtrack      13
# Oldies          13
# Feel Good       13
# Latin           13
# R&B             13
# Funk            13
# Metal           13
# Dance           13
# Soul            13
# Romantic        13
# Meditation      13
# Ballad          13
# Nostalgia       13
# Classical       13
# Acoustic        13
# Rock            13
# Folk            13
# Reggae          13
# Blues           13
# Hip-hop         13
# Electronic      13
# World           13
# Jazz            13
# Indie           13
# EDM             13
# Chill           13
# Comedy          13
# Ambient         13
# Alternative     13
# Name: Genre, dtype: int64

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
# Load the dataset
df = pd.read_csv("/content/music_recommendation_dataset.csv")

# %%
df
# Out:
#                                                Message        Genre
# 0              Excited about starting a new adventure.          Pop
# 1             Feeling nostalgic for the good old days.       Oldies
# 2           Trying to focus and be productive at work.    Classical
# 3    Diving into the timeless beauty of classical c...    Classical
# 4    Journeying through history with the elegance o...    Classical
# ..                                                 ...          ...
# 489  Dancing to the smooth and seductive grooves of...          R&B
# 490  Meditating to the soothing and soul-healing vi...          R&B
# 491  Finding solace in the unconventional rhythms o...  Alternative
# 492  Embracing the complexity of life with alternat...  Alternative
# 493  Exploring the fringes of creativity through al...  Alternative
#
# [494 rows x 2 columns]

# %%
# TF-IDF vectorization
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(data['Message'])

# %%
# Compute the cosine similarity
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
# Create a mapping of indices to messages
indices = pd.Series(data.index, index=data['Message']).to_dict()

# %%
# Function to get genre recommendations
def get_genre_recommendations(message, cosine_sim=cosine_sim):
    idx = indices[message]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]  # Get top 10 recommendations
    similar_indices = [i[0] for i in sim_scores]
    similar_messages = data['Message'].iloc[similar_indices]
    return data['Genre'].loc[data['Message'].isin(similar_messages)]

# %%
# Test the genre recommendation system
input_message = "Excited about starting a new adventure."
genre_recommendations = get_genre_recommendations(input_message)
print(genre_recommendations)
# Out:
# 1            Oldies
# 2         Classical
# 3         Classical
# 4         Classical
# 5         Classical
# 23       Electronic
# 65          Ambient
# 75             Folk
# 311      Soundtrack
# 320    Experimental
# Name: Genre, dtype: object

# %% [markdown]
# # ***Music Model***

# %%
# !pip install spotipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.1/250.1 kB 6.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Preprocess data and create TF-IDF features
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(data['Message'])

# %%
# Encode genre labels
genre_labels = data['Genre'].astype('category').cat.codes

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(tfidf_matrix, genre_labels, test_size=0.2, random_state=42)

# %%
# Train a Random Forest Classifier
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Evaluate the model
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# Model Accuracy: 0.79

# %%
# Save the model to H5 format
import joblib
joblib.dump(model, 'genre_model.pkl')
# Out:
# ['genre_model.pkl']

# %%
# Spotify API integration
client_id = '4afb3295ce3b4efbb48a2862ad03a9d4'
client_secret = '58c8a37749154466bcd2eb9116fe78cd'
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %%
# User input
input_message = "get me some movtivated and chill songs"

# %%
# Predict genre using the trained model
input_message_tfidf = tfidf_vectorizer.transform([input_message])
predicted_genre = model.predict(input_message_tfidf)[0]

# %%
# Get Spotify recommendations based on predicted genre
genre_mapping = {code: genre for code, genre in enumerate(data['Genre'].unique())}
predicted_genre_name = genre_mapping[predicted_genre]
results = sp.search(q=f"genre:{predicted_genre_name}", type='track', limit=10)

# %%
# Display Spotify recommendations
print(f"Spotify Recommendations based on {predicted_genre_name} genre:")
for track in results['tracks']['items']:
    print(f"Track: {track['name']}, Artist: {track['artists'][0]['name']}")
# Out:
# Spotify Recommendations based on Folk genre:
# Track: The Night We Met, Artist: Lord Huron
# Track: Riptide, Artist: Vance Joy
# Track: Brown Eyed Girl, Artist: Van Morrison
# Track: ceilings, Artist: Lizzy McAlpine
# Track: Evergreen, Artist: Richy Mitch & The Coal Miners
# Track: Ophelia, Artist: The Lumineers
# Track: Ho Hey, Artist: The Lumineers
# Track: For What It's Worth, Artist: Buffalo Springfield
# Track: Je te laisserai des mots, Artist: Patrick Watson
# Track: Let Her Go, Artist: Passenger

# %%
import requests
import webbrowser

# Define a function to play a song on YouTube
def play_song(song_name):
    query = song_name.replace(' ', '+')
    url = f"https://www.youtube.com/results?search_query={query}"
    response = requests.get(url)
    search_results = response.text

    # Find the first video link from the search results
    video_link_start = search_results.find('/watch?v=')
    if video_link_start != -1:
        video_link_end = search_results.find('"', video_link_start)
        video_link = search_results[video_link_start:video_link_end]
        video_url = f"https://www.youtube.com{video_link}"
        webbrowser.open(video_url)
        return f"Playing '{song_name}' on YouTube..."
    else:
        return f"No search results found for '{song_name}'."

# Sample Spotify recommendation
recommended_track = track['name']

# Use the function to play the recommended track on YouTube
play_song(recommended_track)
# Out:
# "Playing 'Let Her Go' on YouTube..."

# %%
import joblib
import spotipy
import requests
import webbrowser
from spotipy.oauth2 import SpotifyClientCredentials

# Load the trained model
model = joblib.load('genre_model.pkl')

# Spotify API integration
client_id = '4afb3295ce3b4efbb48a2862ad03a9d4'
client_secret = '58c8a37749154466bcd2eb9116fe78cd'
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# User input
input_message = "get me some motivated and chill songs"

# Predict genre using the trained model
input_message_tfidf = tfidf_vectorizer.transform([input_message])
predicted_genre = model.predict(input_message_tfidf)[0]

# Get Spotify recommendations based on predicted genre
genre_mapping = {code: genre for code, genre in enumerate(data['Genre'].unique())}
predicted_genre_name = genre_mapping[predicted_genre]
results = sp.search(q=f"genre:{predicted_genre_name}", type='track', limit=10)

# Display Spotify recommendations
print(f"Spotify Recommendations based on {predicted_genre_name} genre:")
for index, track in enumerate(results['tracks']['items']):
    print(f"{index + 1}. Track: {track['name']}, Artist: {track['artists'][0]['name']}")

# Ask user if they want to play the recommended tracks
play_all = input("Do you want to play all recommended songs? (yes/no): ").lower()

if play_all == 'yes':
    # Play all recommended tracks
    for track in results['tracks']['items']:
        recommended_track = track['name']
        play_song(recommended_track)
        play_next = input("Do you want to play the next song? (yes/no): ").lower()
        if play_next != 'yes':

            break  # Stop playing songs if user does not want to continue
elif play_all == 'no':
    play_top = input("Do you want to play the topmost recommended song? (yes/no): ").lower()
    if play_top == 'yes':
        recommended_track = results['tracks']['items'][0]['name']
        play_song(recommended_track)

# Ask if the user wants to exit
exit_choice = input("Do you want to exit? (yes/no): ").lower()
if exit_choice == 'yes':
    print("Exiting...")
# Out:
# Spotify Recommendations based on Folk genre:
# 1. Track: The Night We Met, Artist: Lord Huron
# 2. Track: Riptide, Artist: Vance Joy
# 3. Track: Brown Eyed Girl, Artist: Van Morrison
# 4. Track: ceilings, Artist: Lizzy McAlpine
# 5. Track: Evergreen, Artist: Richy Mitch & The Coal Miners
# 6. Track: Ophelia, Artist: The Lumineers
# 7. Track: Ho Hey, Artist: The Lumineers
# 8. Track: For What It's Worth, Artist: Buffalo Springfield
# 9. Track: Je te laisserai des mots, Artist: Patrick Watson
# 10. Track: Let Her Go, Artist: Passenger
# Do you want to play all recommended songs? (yes/no): yes
# Do you want to play the next song? (yes/no): yes
# Do you want to play the next song? (yes/no): no
# Do you want to exit? (yes/no): yes
# Exiting...
